# %% [markdown]
# # United States of America: The Data

# %% [markdown]
# Testing functions and parts of code to be combined

# %%
import data_manage as dm
import pandas as pd

# %%
gdf = dm.load_shape("house")
gdf.head(2)
# Out:
#   STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN        ALAND      AWATER  \
# 0      06      40  5001500US0640  0640   C2     115    149408224     1743217
# 1      06      02  5001500US0602  0602   C2     115  33546252741  4122497535
#
#                                             geometry STATEFP_let
# 0  POLYGON ((-118.280958 34.005589, -118.280939 3...          CA
# 1  (POLYGON ((-122.446316 37.861046, -122.441271 ...          CA

# %%
mdf = dm.member_dataframe("115","house")
mdf.head(2)
# Out:
#                                              api_uri  at_large contact_form  \
# 0  https://api.propublica.org/congress/v1/members...     False         None
# 1  https://api.propublica.org/congress/v1/members...     False         None
#
#       crp_id cspan_id date_of_birth district  dw_nominate  \
# 0  N00036633    76236    1954-09-16        5        0.497
# 1  N00035451    76386    1946-05-27       12       -0.465
#
#           facebook_account           fax       ...        state suffix  \
# 0  CongressmanRalphAbraham  202-225-5639       ...           LA   None
# 1       CongresswomanAdams  202-225-1512       ...           NC   None
#
#             title total_present total_votes twitter_account  \
# 0  Representative           0.0       878.0      RepAbraham
# 1  Representative           0.0       878.0        RepAdams
#
#                          url votes_with_party_pct votesmart_id  \
# 0  https://abraham.house.gov                97.01       155414
# ...

# %%
dm.member_img("A000360")

# %%
mdf = dm.clean_house(mdf)
mdf.head(2)
# Out:
#                                                  api_uri  at_large  \
# ident
# LA05   https://api.propublica.org/congress/v1/members...     False
# NC12   https://api.propublica.org/congress/v1/members...     False
#
#       contact_form     crp_id cspan_id date_of_birth district  dw_nominate  \
# ident
# LA05          None  N00036633    76236    1954-09-16       05        0.497
# NC12          None  N00035451    76386    1946-05-27       12       -0.465
#
#               facebook_account           fax       ...        state suffix  \
# ident                                              ...
# LA05   CongressmanRalphAbraham  202-225-5639       ...           LA   None
# NC12        CongresswomanAdams  202-225-1512       ...           NC   None
#
#                 title total_present total_votes twitter_account  \
# ident
# LA05   Representative           0.0       878.0      RepAbraham
# NC12   Representative           0.0       878.0        RepAdams
#
# ...

# %%
gdf = dm.clean_shape(gdf)
gdf.head(2)
# Out:
#       STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN        ALAND  \
# ident
# CA40       06      40  5001500US0640  0640   C2     115    149408224
# CA02       06      02  5001500US0602  0602   C2     115  33546252741
#
#            AWATER                                           geometry  \
# ident
# CA40      1743217  POLYGON ((-118.280958 34.005589, -118.280939 3...
# CA02   4122497535  (POLYGON ((-122.446316 37.861046, -122.441271 ...
#
#       STATEFP_let
# ident
# CA40           CA
# CA02           CA

# %%
tot_df = dm.join_mem_shape(gdf,mdf)
tot_df.head(2)
# Out:
#       STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN          ALAND  \
# ident
# 6998       69      98  5001500US6998  6998   C4     115      472276664
# AK00       02      00  5001500US0200  0200   C1     115  1477946266785
#
#              AWATER                                           geometry  \
# ident
# 6998     4644268325  (POLYGON ((146.051034 16.006741, 146.051668 16...
# AK00   245390495931  (POLYGON ((-176.055151 51.933885, -176.053012 ...
#
#       STATEFP_let       ...       state suffix           title total_present  \
# ident                   ...
# 6998           69       ...         NaN    NaN             NaN           NaN
# AK00           AK       ...          AK   None  Representative           0.0
#
#       total_votes twitter_account                         url  \
# ident
# 6998          NaN             NaN                         NaN
# AK00        878.0     RepDonYoung  https://donyoung.house.gov
#
#        votes_with_party_pct votesmart_id youtube_account
# ...

# %%
tot_df = tot_df[(tot_df['title']== "Representative") & (tot_df['in_office']== True)]
tot_df.head(2)
# Out:
#       STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN          ALAND  \
# ident
# AK00       02      00  5001500US0200  0200   C1     115  1477946266785
# AL01       01      01  5001500US0101  0101   C2     115    15713033442
#
#              AWATER                                           geometry  \
# ident
# AK00   245390495931  (POLYGON ((-176.055151 51.933885, -176.053012 ...
# AL01     2275872161  (POLYGON ((-88.053375 30.506987, -88.051087999...
#
#       STATEFP_let       ...       state suffix           title total_present  \
# ident                   ...
# AK00           AK       ...          AK   None  Representative           0.0
# AL01           AL       ...          AL   None  Representative           0.0
#
#       total_votes twitter_account                         url  \
# ident
# AK00        878.0     RepDonYoung  https://donyoung.house.gov
# AL01        878.0        RepByrne     https://byrne.house.gov
#
#        votes_with_party_pct votesmart_id youtube_account
# ...

# %% [markdown]
# for x in tot_df['id']:
#     dm.member_img(str(x))

# %%
b_map = dm.party_map_html_pop(tot_df)
dm.write_map(b_map,outname="another_tester.html")

# %%
tot_df.head(2)
tot_df.to_pickle('house_data.pand')

# %%
import pickle
import pandas as pd 
new_data = pd.read_pickle("house_data.pand")
new_data.head(2)

# %%
tot_df.head()
tot_df.columns
# Out:
# Index(['STATEFP', 'CD115FP', 'AFFGEOID', 'GEOID', 'LSAD', 'CDSESSN', 'ALAND',
#        'AWATER', 'geometry', 'STATEFP_let', 'api_uri', 'at_large',
#        'contact_form', 'crp_id', 'cspan_id', 'date_of_birth', 'district',
#        'dw_nominate', 'facebook_account', 'fax', 'fec_candidate_id',
#        'first_name', 'gender', 'geoid', 'google_entity_id', 'govtrack_id',
#        'icpsr_id', 'id', 'ideal_point', 'in_office', 'last_name',
#        'leadership_role', 'middle_name', 'missed_votes', 'missed_votes_pct',
#        'next_election', 'ocd_id', 'office', 'party', 'phone', 'rss_url',
#        'seniority', 'short_title', 'state', 'suffix', 'title', 'total_present',
#        'total_votes', 'twitter_account', 'url', 'votes_with_party_pct',
#        'votesmart_id', 'youtube_account'],
#       dtype='object')

# %%
import data_manage as dm
import pandas as pd
import numpy as np

# %%
gdf = dm.load_shape("senate")
gdf.head(2)
# Out:
#    STATE_NAME  DRAWSEQ STATE_FIPS SUB_REGION STATE_ABBR  \
# 0      Hawaii        1         15    Pacific         HI
# 1  Washington        2         53    Pacific         WA
#
#                                             geometry
# 0  (POLYGON ((-160.0738033454681 22.0041773479577...
# 1  (POLYGON ((-122.4020153103835 48.2252163723779...

# %%
mdf = dm.member_dataframe("115","senate")
mdf.head(2)
# Out:
#                                              api_uri  \
# 0  https://api.propublica.org/congress/v1/members...
# 1  https://api.propublica.org/congress/v1/members...
#
#                                         contact_form     crp_id cspan_id  \
# 0  http://www.alexander.senate.gov/public/index.c...  N00009888        5
# 1            https://www.baldwin.senate.gov/feedback  N00004367    57884
#
#   date_of_birth  dw_nominate       facebook_account           fax  \
# 0    1940-07-03        0.323  senatorlamaralexander  202-228-3398
# 1    1962-02-11       -0.536           TammyBaldwin  202-225-6942
#
#   fec_candidate_id first_name       ...       state_rank suffix  \
# 0        S2TN00058      Lamar       ...           senior   None
# 1        S2WI00219      Tammy       ...           junior   None
#
#                 title total_present total_votes twitter_account  \
# 0  Senator, 2nd Class             0         410    SenAlexander
# ...

# %%
tot_sen = dm.join_senate_shape(gdf,mdf)
#for x in tot_sen['id']:
#    dm.member_img(str(x))
tot_sen = dm.clean(tot_sen)
tot_sen
# Out:
#               STATE_NAME  DRAWSEQ STATE_FIPS          SUB_REGION  \
# AK                Alaska       51         02             Pacific
# AK                Alaska       51         02             Pacific
# AL               Alabama       43         01  East South Central
# AL               Alabama       43         01  East South Central
# AL               Alabama       43         01  East South Central
# AL               Alabama       43         01  East South Central
# AR              Arkansas       47         05  West South Central
# AR              Arkansas       47         05  West South Central
# AZ               Arizona       37         04            Mountain
# AZ               Arizona       37         04            Mountain
# CA            California       25         06             Pacific
# CA            California       25         06             Pacific
# CO              Colorado       32         08            Mountain
# ...

# %%
tot_sen['state_rank']= tot_sen['state_rank'].replace(np.nan, '', regex=True)
test1 = tot_sen[tot_sen['state_rank'] != '']
tot_sen.head(2)
# Out:
#    STATE_NAME  DRAWSEQ STATE_FIPS SUB_REGION  \
# AK     Alaska       51         02    Pacific
# AK     Alaska       51         02    Pacific
#
#                                              geometry  \
# AK  (POLYGON ((-161.3337853466416 58.7332483821643...
# AK  (POLYGON ((-161.3337853466416 58.7332483821643...
#
#                                               api_uri  \
# AK  https://api.propublica.org/congress/v1/members...
# AK  https://api.propublica.org/congress/v1/members...
#
#                                          contact_form     crp_id cspan_id  \
# AK  https://www.murkowski.senate.gov/public/index....  N00026050  1004138
# AK      https://www.sullivan.senate.gov/contact/email  N00035774  1023262
#
#    date_of_birth        ...         state_rank suffix               title  \
# AK    1957-05-22        ...             senior   None  Senator, 3rd Class
# AK    1964-11-13        ...             junior   None  Senator, 2nd Class
#
# ...

# %%
# Out:
# Empty GeoDataFrame
# Columns: [STATE_NAME, DRAWSEQ, STATE_FIPS, SUB_REGION, geometry, api_uri, contact_form, crp_id, cspan_id, date_of_birth, dw_nominate, facebook_account, fax, fec_candidate_id, first_name, gender, google_entity_id, govtrack_id, icpsr_id, id, ideal_point, in_office, last_name, leadership_role, lis_id, middle_name, missed_votes, missed_votes_pct, next_election, ocd_id, office, party, phone, rss_url, senate_class, seniority, short_title, state_rank, suffix, title, total_present, total_votes, twitter_account, url, votes_with_party_pct, votesmart_id, youtube_account]
# Index: []
#
# [0 rows x 47 columns]

# %%
sen_map = dm.party_map_html_pop(test1[test1['state_rank']=='senior'])
jun_map = dm.party_map_html_pop(test1[test1['state_rank']=='junior'])

dm.write_map(sen_map, 'senior.html')
dm.write_map(jun_map, 'junior.html')

sen_map = dm.party_map_html_pop(test1)
dm.write_map(sen_map,'all_senate.html')

# %%
from IPython.display import IFrame
IFrame('all_senate.html', width=950, height=500)
# Out:
#         <iframe
#             width="950"
#             height="500"
#             src="all_senate.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
#  Wikipedia image scrape by name.

# %%
import wikipedia
import requests
name1 = "Ralph Abraham"
ny1 = wikipedia.search(name1)
name = name1
for n in ny1:
    if "(politician)" in n:
        name = n
ny = wikipedia.page(name)
print(ny)
print(ny.images)

img_data = requests.get(ny.images[0]).content
with open(ny.title+'.jpg', 'wb') as handler:
    handler.write(img_data)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1715         result = _lib.SSL_do_handshake(self._ssl)
# -> 1716         self._raise_ssl_error(self._ssl, result)
#    1717
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1455         else:
# -> 1456             _raise_current_error()
#    1457
#
# ...
