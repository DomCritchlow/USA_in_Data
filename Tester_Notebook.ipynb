# %% [markdown]
# # United States of America: The Data

# %% [markdown]
# Testing functions and parts of code to be combined

# %%
import data_manage as dm

# %%
gdf = dm.load_shape("house")
dm.simple_map_html(gdf,"tester.html")
gdf.head(2)
# Out:
#   STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN        ALAND      AWATER  \
# 0      06      40  5001500US0640  0640   C2     115    149408224     1743217
# 1      06      02  5001500US0602  0602   C2     115  33546252741  4122497535
#
#                                             geometry STATEFP_let
# 0  POLYGON ((-118.280958 34.005589, -118.280939 3...          CA
# 1  (POLYGON ((-122.446316 37.861046, -122.441271 ...          CA

# %%
mdf = dm.member_dataframe("115","house")
mdf.head(2)
# Out:
# [{'id': 'A000374', 'title': 'Representative', 'short_title': 'Rep.', 'api_uri': 'https://api.propublica.org/congress/v1/members/A000374.json', 'first_name': 'Ralph', 'middle_name': None, 'last_name': 'Abraham', 'suffix': None, 'date_of_birth': '1954-09-16', 'gender': 'M', 'party': 'R', 'leadership_role': None, 'twitter_account': 'RepAbraham', 'facebook_account': 'CongressmanRalphAbraham', 'youtube_account': None, 'govtrack_id': '412630', 'cspan_id': '76236', 'votesmart_id': '155414', 'icpsr_id': '21522', 'crp_id': 'N00036633', 'google_entity_id': '/m/012dwd7_', 'fec_candidate_id': 'H4LA05221', 'url': 'https://abraham.house.gov', 'rss_url': 'https://abraham.house.gov/rss.xml', 'contact_form': None, 'in_office': True, 'dw_nominate': 0.497, 'ideal_point': None, 'seniority': '4', 'next_election': '2018', 'total_votes': 878, 'missed_votes': 8, 'total_present': 0, 'ocd_id': 'ocd-division/country:us/state:la/cd:5', 'office': '417 Cannon House Office Building', 'phone': '202-225-8490', 'fax': '202-225-5639', 'state': 'LA', 'district': '5', 'at_large': False, 'geoid': '2205', 'missed_votes_pct': 0.91, 'votes_with_party_pct': 97.01}, {'id': 'A000370', 'title': 'Representative', 'short_title': 'Rep.', 'api_uri': 'https://api.propublica.org/congress/v1/members/A000370.json', 'first_name': 'Alma', 'middle_name': None, 'last_name': 'Adams', 'suffix': None, 'date_of_birth': '1946-05-27', 'gender': 'F', 'party': 'D', 'leadership_role': None, 'twitter_account': 'RepAdams', 'facebook_account': 'CongresswomanAdams', 'youtube_account': None, 'govtrack_id': '412607', 'cspan_id': '76386', 'votesmart_id': '5935', 'icpsr_id': '21545', 'crp_id': 'N00035451', 'google_entity_id': '/m/02b45d', 'fec_candidate_id': 'H4NC12100', 'url': 'https://adams.house.gov', 'rss_url': 'https://adams.house.gov/rss.xml', 'contact_form': None, 'in_office': True, 'dw_nominate': -0.465, 'ideal_point': None, 'seniority': '6', 'next_election': '2018', 'total_votes': 878, 'missed_votes': 20, 'total_present': 0, 'ocd_id': 'ocd-division/country:us/state:nc/cd:12', 'office': '222 Cannon House Office Building', 'phone': '202-225-1510', 'fax': '202-225-1512', 'state': 'NC', 'district': '12', 'at_large': False, 'geoid': '3712', 'missed_votes_pct': 2.28, 'votes_with_party_pct': 95.69}, {'id': 'A000055', 'title': 'Representative', 'short_title': 'Rep.', 'api_uri': 'https://api.propublica.org/congress/v1/members/A000055.json', 'first_name': 'Robert', 'middle_name': 'B.', 'last_name': 'Aderholt', 'suffix': None, 'date_of_birth': '1965-07-22', 'gender': 'M', 'party': 'R', 'leadership_role': None, 'twitter_account': 'Robert_Aderholt', 'facebook_account': 'RobertAderholt', 'youtube_account': 'RobertAderholt', 'govtrack_id': '400004', 'cspan_id': '45516', 'votesmart_id': '441', 'icpsr_id': '29701', 'crp_id': 'N00003028', 'google_entity_id': '/m/024p03', 'fec_candidate_id': 'H6AL04098', 'url': 'https://aderholt.house.gov', 'rss_url': 'https://aderholt.house.gov/rss.xml', 'contact_form': None, 'in_office': True, 'dw_nominate': 0.36, 'ideal_point': None, 'seniority': '22', 'next_election': '2018', 'total_votes': 878, 'missed_votes': 29, 'total_present': 0, 'ocd_id': 'ocd-division/country:us/state:al/cd:4', 'office': '235 Cannon House Office Building', 'phone': '202-225-4876', 'fax': '202-225-5587', 'state': 'AL', 'district': '4', 'at_large': False, 'geoid': '0104', 'missed_votes_pct': 3.3, 'votes_with_party_pct': 96.58}, {'id': 'A000371', 'title': 'Representative', 'short_title': 'Rep.', 'api_uri': 'https://api.propublica.org/congress/v1/members/A000371.json', 'first_name': 'Pete', 'middle_name': None, 'last_name': 'Aguilar', 'suffix': None, 'date_of_birth': '1979-06-19', 'gender': 'M', 'party': 'D', 'leadership_role': None, 'twitter_account': 'reppeteaguilar', 'facebook_account': 'reppeteaguilar', 'youtube_account': None, 'govtrack_id': '412615', 'cspan_id': '79994', 'votesmart_id': '70114', 'icpsr_id': '21506', 'crp_id': 'N00033997', 'google_entity_id': '/m/0jwv0xf', 'fec_candidate_id': 'H2C ...
#                                              api_uri  at_large contact_form  \
# 0  https://api.propublica.org/congress/v1/members...     False         None
# 1  https://api.propublica.org/congress/v1/members...     False         None
#
#       crp_id cspan_id date_of_birth district  dw_nominate  \
# 0  N00036633    76236    1954-09-16        5        0.497
# 1  N00035451    76386    1946-05-27       12       -0.465
#
#           facebook_account           fax       ...        state suffix  \
# 0  CongressmanRalphAbraham  202-225-5639       ...           LA   None
# 1       CongresswomanAdams  202-225-1512       ...           NC   None
#
#             title total_present total_votes twitter_account  \
# 0  Representative           0.0       878.0      RepAbraham
# 1  Representative           0.0       878.0        RepAdams
#
#                          url votes_with_party_pct votesmart_id  \
# 0  https://abraham.house.gov                97.01       155414
# 1    https://adams.house.gov                95.69         5935
#
#    youtube_account
# 0             None
# 1             None
#
# [2 rows x 43 columns]

# %%
dm.member_img("A000360")

# %%
gdf[gdf['CD115FP']== '00']
# Out:
#     STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN          ALAND  \
# 40       56      00  5001500US5600  5600   C1     115   251464935120
# 88       30      00  5001500US3000  3000   C1     115   376964956503
# 216      02      00  5001500US0200  0200   C1     115  1477946266785
# 217      38      00  5001500US3800  3800   C1     115   178711813026
# 224      46      00  5001500US4600  4600   C1     115   196348407642
# 400      10      00  5001500US1000  1000   C1     115     5047194742
# 418      50      00  5001500US5000  5000   C1     115    23873467535
#
#            AWATER                                           geometry  \
# 40     1861273298  POLYGON ((-111.056888 44.866658, -111.055629 4...
# 88     3866986696  POLYGON ((-116.049667201931 48.4403221865285, ...
# 216  245390495931  (POLYGON ((-176.055151 51.933885, -176.053012 ...
# 217    4399093501  POLYGON ((-104.048652 48.865734, -104.048824 4...
# 224    3380782733  POLYGON ((-104.057698 44.997431, -104.049505 4...
# 400    1398720828  (POLYGON ((-75.565546 39.51485, -75.5617429999...
# 418    1031124865  POLYGON ((-73.43773999999999 44.045006, -73.43...
#
#     STATEFP_let
# 40           WY
# 88           MT
# 216          AK
# 217          ND
# 224          SD
# 400          DE
# 418          VT

# %%
mdf.head(2)
mdf['state']

mask = mdf.district == "At-Large"
mdf.loc[mask, 'district'] = '00'


mdf['district'] = mdf['district'].apply(lambda x: x.zfill(2))
mdf['district']

mdf['ident']= mdf['state']+ mdf['district'] 
mdf['ident'] = mdf['ident'].astype(str)
mdf.set_index('ident',inplace=True)
mdf.head(2)
# Out:
#                                                  api_uri  at_large  \
# ident
# LA05   https://api.propublica.org/congress/v1/members...     False
# NC12   https://api.propublica.org/congress/v1/members...     False
#
#       contact_form     crp_id cspan_id date_of_birth district  dw_nominate  \
# ident
# LA05          None  N00036633    76236    1954-09-16       05        0.497
# NC12          None  N00035451    76386    1946-05-27       12       -0.465
#
#               facebook_account           fax       ...        state suffix  \
# ident                                              ...
# LA05   CongressmanRalphAbraham  202-225-5639       ...           LA   None
# NC12        CongresswomanAdams  202-225-1512       ...           NC   None
#
#                 title total_present total_votes twitter_account  \
# ident
# LA05   Representative           0.0       878.0      RepAbraham
# NC12   Representative           0.0       878.0        RepAdams
#
#                              url votes_with_party_pct votesmart_id  \
# ident
# LA05   https://abraham.house.gov                97.01       155414
# NC12     https://adams.house.gov                95.69         5935
#
#        youtube_account
# ident
# LA05              None
# NC12              None
#
# [2 rows x 43 columns]

# %%
gdf['ident'] = gdf['STATEFP_let'] + gdf['CD115FP']
gdf.sort_values('ident')
gdf.head(2)
gdf['ident'] = gdf['ident'].astype(str)

gdf.set_index('ident',inplace=True)

gdf.head(2)
# Out:
#       STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN        ALAND  \
# ident
# CA40       06      40  5001500US0640  0640   C2     115    149408224
# CA02       06      02  5001500US0602  0602   C2     115  33546252741
#
#            AWATER                                           geometry  \
# ident
# CA40      1743217  POLYGON ((-118.280958 34.005589, -118.280939 3...
# CA02   4122497535  (POLYGON ((-122.446316 37.861046, -122.441271 ...
#
#       STATEFP_let
# ident
# CA40           CA
# CA02           CA

# %%
total_df = gdf.join(mdf,how='left',lsuffix='_l',rsuffix='_r')
total_df
# Out:
#       STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN          ALAND  \
# ident
# 6998       69      98  5001500US6998  6998   C4     115      472276664
# AK00       02      00  5001500US0200  0200   C1     115  1477946266785
# AL01       01      01  5001500US0101  0101   C2     115    15713033442
# AL02       01      02  5001500US0102  0102   C2     115    26266769386
# WA01     1095973781  (POLYGON ((-122.593346 48.651424, -122.587158 ...
# WA02     2683877037  (POLYGON ((-122.33164 48.020556, -122.328343 4...
# WA03     1220473042  POLYGON ((-124.0983430316 46.7940669968361, -1...
# WA04      808793946  POLYGON ((-121.520284 46.879177, -121.513265 4...
# WA05      598905520  POLYGON ((-118.979518 47.349532, -118.978798 4...
# WA06     5100417092  (POLYGON ((-122.504923 47.54653099999999, -122...
# WA07      341471890  (POLYGON ((-122.436941 47.661719, -122.425506 ...
# WA08      369722448  POLYGON ((-122.560436 46.933457, -122.55648 46...
# WA09      104638814  POLYGON ((-122.444353 47.306099, -122.434617 4...
# WA10      234177529  (POLYGON ((-122.640638 47.149413, -122.638649 ...
# WI01     2523908462  POLYGON ((-89.080665 42.675151, -89.079188 42....
# WI02      189149076  POLYGON ((-90.42990999999999 43.118213, -90.42...
# WI03      826968563  POLYGON ((-92.807362 44.758909, -92.8061185221...
# WI04     2454242370  POLYGON ((-88.07031599999999 43.122701, -88.07...
# WI05      165147915  POLYGON ((-89.013578 42.84928499999999, -89.01...
# WI06     7317994714  POLYGON ((-89.78490099999999 43.641051, -89.77...
# WI07     7701303765  (POLYGON ((-90.46546499999999 47.002593, -90.4...
# WI08     8182671615  (POLYGON ((-86.95616699999999 45.355489, -86.9...
# WV01      176317347  POLYGON ((-81.7558150545194 39.1805241965567, ...
# WV02      121810592  POLYGON ((-82.064562 38.607985, -82.0214209999...
# WV03      191774877  POLYGON ((-82.6431981036679 38.1690897960737, ...
# WY00     1861273298  POLYGON ((-111.056888 44.866658, -111.055629 4...
#
#       STATEFP_let          ...          state suffix           title  \
# ident                      ...
# 6998           69          ...            NaN    NaN             NaN
# AK00           AK          ...             AK   None  Representative
# AL01           AL          ...             AL   None  Representative
# AL02           AL          ...             AL   None  Representative
# AL03           AL          ...             AL   None  Representative
# AL04           AL          ...             AL   None  Representative
# AL05           AL          ...             AL   None  Representative
# AL06           AL          ...             AL   None  Representative
# AL07           AL          ...             AL   None  Representative
# AR01           AR          ...             AR   None  Representative
# AR02           AR          ...             AR   None  Representative
# AR03           AR          ...             AR   None  Representative
# AR04           AR          ...             AR   None  Representative
# AS98           AS          ...            NaN    NaN             NaN
# AZ01           AZ          ...             AZ   None  Representative
# AZ02           AZ          ...             AZ   None  Representative
# AZ03           AZ          ...             AZ   None  Representative
# AZ04           AZ          ...             AZ   None  Representative
# AZ05           AZ          ...             AZ   None  Representative
# AZ06           AZ          ...             AZ   None  Representative
# AZ07           AZ          ...             AZ   None  Representative
# AZ08           AZ          ...             AZ   None  Representative
# AZ09           AZ          ...             AZ   None  Representative
# CA01           CA          ...             CA   None  Representative
# CA02           CA          ...             CA   None  Representative
# CA03           CA          ...             CA   None  Representative
# CA04           CA          ...             CA   None  Representative
# CA05           CA          ...             CA   None  Representative
# CA06           CA          ...             CA   None  Representative
# CA07           CA          ...             CA   None  Representative
# ...           ...          ...            ...    ...             ...
# VA06           VA          ...             VA   None  Representative
# VA07           VA          ...             VA   None  Representative
# VA08           VA          ...             VA   None  Representative
# VA09           VA          ...             VA   None  Representative
# VA10           VA          ...             VA   None  Representative
# VA11           VA          ...             VA   None  Representative
# VI98           VI          ...            NaN    NaN             NaN
# VT00           VT          ...             VT   None  Representative
# WA01           WA          ...             WA   None  Representative
# WA02           WA          ...             WA   None  Representative
# WA03           WA          ...             WA   None  Representative
# WA04           WA          ...             WA   None  Representative
# WA05           WA          ...             WA   None  Representative
# WA06           WA          ...             WA   None  Representative
# WA07           WA          ...             WA   None  Representative
# WA08           WA          ...             WA   None  Representative
# WA09           WA          ...             WA   None  Representative
# WA10           WA          ...             WA   None  Representative
# WI01           WI          ...             WI   None  Representative
# WI02           WI          ...             WI   None  Representative
# WI03           WI          ...             WI   None  Representative
# WI04           WI          ...             WI   None  Representative
# WI05           WI          ...             WI   None  Representative
# WI06           WI          ...             WI   None  Representative
# WI07           WI          ...             WI   None  Representative
# WI08           WI          ...             WI   None  Representative
# WV01           WV          ...             WV   None  Representative
# WV02           WV          ...             WV   None  Representative
# WV03           WV          ...             WV   None  Representative
# WY00           WY          ...             WY   None  Representative
#
#       total_present total_votes  twitter_account  \
# ident
# 6998            NaN         NaN              NaN
# AK00            0.0       878.0      RepDonYoung
# AL01            0.0       878.0         RepByrne
# AL02            0.0       878.0    RepMarthaRoby
# AL03            0.0       878.0  RepMikeRogersAL
# AL04            0.0       878.0  Robert_Aderholt
# AL05            0.0       878.0      RepMoBrooks
# AL06            0.0       878.0  USRepGaryPalmer
# AL07            1.0       878.0   RepTerriSewell
# AR01            0.0       878.0  RepRickCrawford
# AR02            0.0       878.0    RepFrenchHill
# AR03            0.0       878.0  Rep_SteveWomack
# AR04            0.0       878.0     RepWesterman
# AS98            NaN         NaN              NaN
# AZ01            0.0       878.0     repohalleran
# AZ02            0.0       878.0       RepMcSally
# AZ03            2.0       878.0  RepraulGrijalva
# AZ04            0.0       878.0         RepGosar
# AZ05            0.0       878.0   RepAndyBiggsAZ
# AZ06            0.0       878.0         RepDavid
# AZ07            0.0       878.0  RepRubenGallego
# AZ08            0.0       673.0   RepTrentFranks
# AZ09            0.0       878.0        RepSinema
# CA01            0.0       878.0       RepLaMalfa
# CA02            0.0       878.0       RepHuffman
# CA03            1.0       878.0     RepGaramendi
# CA04            0.0       878.0    RepMcClintock
# CA05            0.0       878.0      RepThompson
# CA06            0.0       878.0      DorisMatsui
# CA07            0.0       878.0          RepBera
# ...             ...         ...              ...
# VA06            0.0       878.0     RepGoodlatte
# VA07            0.0       878.0      RepDaveBrat
# VA08            0.0       878.0      repdonbeyer
# VA09            2.0       878.0     RepMGriffith
# VA10            0.0       878.0      RepComstock
# VA11            0.0       878.0    GerryConnolly
# VI98            NaN         NaN              NaN
# VT00            0.0       878.0       PeterWelch
# WA01            0.0       878.0       RepDelBene
# WA02            0.0       878.0    RepRickLarsen
# WA03            0.0       878.0   HerreraBeutler
# WA04            0.0       878.0      RepNewhouse
# WA05            0.0       878.0    CathyMcMorris
# WA09        https://adamsmith.house.gov                 93.20          845
# WA10        https://dennyheck.house.gov                 93.03       126058
# WI01         https://paulryan.house.gov                 87.50        26344
# WI02            https://pocan.house.gov                 94.24        26238
# WI03             https://kind.house.gov                 90.01          630
# WI04        https://gwenmoore.house.gov                 93.43         3457
# WI05    https://sensenbrenner.house.gov                 95.18        27142
# WI06         https://grothman.house.gov                 94.39         3493
# WI07            https://duffy.house.gov                 94.30       126238
# WI08        https://gallagher.house.gov                 93.01       171843
# WV01         https://mckinley.house.gov                 90.06       117396
# WV02           https://mooney.house.gov                 94.11       145943
# WV03      https://evanjenkins.house.gov                 92.10         8297
# WY00           https://cheney.house.gov                 96.43       145932
#
#             youtube_account
# ident
# 6998                    NaN
# AK00            RepDonYoung
# AL01                   None
# AL02                reproby
# AL03         MikeRogersAL03
# AL04         RobertAderholt
# AL05            RepMoBrooks
# AL06                   None
# AL07              RepSewell
# AR01        RepRickCrawford
# AR02                   None
# AR03      CongressmanWomack
# AR04                   None
# AS98                    NaN
# AZ01                   None
# AZ02                   None
# AZ03       raulgrijalvaaz07
# AZ04               repgosar
# AZ05                   None
# AZ06     RepDavidSchweikert
# AZ07                   None
# AZ08                   None
# AZ09              repsinema
# CA01             RepLaMalfa
# CA02             rephuffman
# CA03          garamendiCA10
# CA04         McClintockCA04
# CA05   CongressmanMThompson
# CA06         RepDorisMatsui
# CA07             repamibera
# ...                     ...
# VA06        RepBobGoodlatte
# VA07                   None
# VA08                   None
# VA09      RepMorganGriffith
# VA10                   None
# VA11            repconnolly
# VI98                    NaN
# VT00          reppeterwelch
# WA01                   None
# WA02      congressmanlarsen
# WA03      RepHerreraBeutler
# WA04                   None
# WA05        mcmorrisrodgers
# WA06                   None
# WA07                   None
# WA08        repdavereichert
# WA09   CongressmanAdamSmith
# WA10           RepDennyHeck
# WI01            reppaulryan
# WI02           repmarkpocan
# WI03             RepRonKind
# WI04           RepGwenMoore
# WI05       RepSensenbrenner
# WI06                   None
# WI07           RepSeanDuffy
# WI08                   None
# WV01       RepDavidMcKinley
# WV02                   None
# WV03                   None
# WY00                   None
#
# [448 rows x 53 columns]

# %%
total_df = total_df[(total_df['title']== "Representative") & (total_df['in_office']== True)]
total_df
# Out:
#       STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN          ALAND  \
# ident
# AK00       02      00  5001500US0200  0200   C1     115  1477946266785
# AL01       01      01  5001500US0101  0101   C2     115    15713033442
# AL02       01      02  5001500US0102  0102   C2     115    26266769386
# AL03       01      03  5001500US0103  0103   C2     115    19539111289
# AL04       01      04  5001500US0104  0104   C2     115    23022867957
# AL05       01      05  5001500US0105  0105   C2     115     9524306180
# AL06       01      06  5001500US0106  0106   C2     115    10803490973
# AL07       01      07  5001500US0107  0107   C2     115    26304109724
# AR01       05      01  5001500US0501  0501   C2     115    50036314981
# AR02       05      02  5001500US0502  0502   C2     115    12894845468
# AR03       05      03  5001500US0503  0503   C2     115    13983502473
# AR04       05      04  5001500US0504  0504   C2     115    57856854674
# WA07           WA            ...               WA   None  Representative
# WA08           WA            ...               WA   None  Representative
# WA09           WA            ...               WA   None  Representative
# WA10           WA            ...               WA   None  Representative
# WI01           WI            ...               WI   None  Representative
# WI02           WI            ...               WI   None  Representative
# WI03           WI            ...               WI   None  Representative
# WI04           WI            ...               WI   None  Representative
# WI05           WI            ...               WI   None  Representative
# WI06           WI            ...               WI   None  Representative
# WI07           WI            ...               WI   None  Representative
# WI08           WI            ...               WI   None  Representative
# WV01           WV            ...               WV   None  Representative
# WV02           WV            ...               WV   None  Representative
# WV03           WV            ...               WV   None  Representative
# WY00           WY            ...               WY   None  Representative
#
#       total_present total_votes  twitter_account  \
# ident
# AK00            0.0       878.0      RepDonYoung
# AL01            0.0       878.0         RepByrne
# AL02            0.0       878.0    RepMarthaRoby
# AL03            0.0       878.0  RepMikeRogersAL
# AL04            0.0       878.0  Robert_Aderholt
# AL05            0.0       878.0      RepMoBrooks
# AL06            0.0       878.0  USRepGaryPalmer
# AL07            1.0       878.0   RepTerriSewell
# AR01            0.0       878.0  RepRickCrawford
# AR02            0.0       878.0    RepFrenchHill
# AR03            0.0       878.0  Rep_SteveWomack
# AR04            0.0       878.0     RepWesterman
# AZ01            0.0       878.0     repohalleran
# AZ02            0.0       878.0       RepMcSally
# AZ03            2.0       878.0  RepraulGrijalva
# AZ04            0.0       878.0         RepGosar
# AZ05            0.0       878.0   RepAndyBiggsAZ
# AZ06            0.0       878.0         RepDavid
# AZ07            0.0       878.0  RepRubenGallego
# AZ09            0.0       878.0        RepSinema
# CA01            0.0       878.0       RepLaMalfa
# CA02            0.0       878.0       RepHuffman
# CA03            1.0       878.0     RepGaramendi
# CA04            0.0       878.0    RepMcClintock
# CA05            0.0       878.0      RepThompson
# CA06            0.0       878.0      DorisMatsui
# CA07            0.0       878.0          RepBera
# CA08            0.0       878.0      RepPaulCook
# CA09            0.0       878.0      RepMcNerney
# CA10            0.0       878.0    RepJeffDenham
# ...             ...         ...              ...
# VA05            0.0       878.0    RepTomGarrett
# VA06            0.0       878.0     RepGoodlatte
# VA07            0.0       878.0      RepDaveBrat
# VA08            0.0       878.0      repdonbeyer
# VA09            2.0       878.0     RepMGriffith
# VA10            0.0       878.0      RepComstock
# VA11            0.0       878.0    GerryConnolly
# VT00            0.0       878.0       PeterWelch
# WA01            0.0       878.0       RepDelBene
# WA02            0.0       878.0    RepRickLarsen
# WA03            0.0       878.0   HerreraBeutler
# WA04            0.0       878.0      RepNewhouse
# WA05            0.0       878.0    CathyMcMorris
# WA06            0.0       878.0   RepDerekKilmer
# WA07            0.0       878.0       RepJayapal
# WA08            0.0       878.0     DaveReichert
# WA09            0.0       878.0     RepAdamSmith
# WA10            0.0       878.0     RepDennyHeck
# WI01            0.0       878.0      SpeakerRyan
# WI02            0.0       878.0     RepMarkPocan
# WI03            0.0       878.0       RepRonKind
# WI04            0.0       878.0     RepGwenMoore
# WI05            0.0       878.0   JimPressOffice
# WI06            0.0       878.0      RepGrothman
# WI07            0.0       878.0     RepSeanDuffy
# WI08        https://gallagher.house.gov                 93.01       171843
# WV01         https://mckinley.house.gov                 90.06       117396
# WV02           https://mooney.house.gov                 94.11       145943
# WV03      https://evanjenkins.house.gov                 92.10         8297
# WY00           https://cheney.house.gov                 96.43       145932
#
#                 youtube_account
# ident
# AK00                RepDonYoung
# AL01                       None
# AL02                    reproby
# AL03             MikeRogersAL03
# AL04             RobertAderholt
# AL05                RepMoBrooks
# AL06                       None
# AL07                  RepSewell
# AR01            RepRickCrawford
# AR02                       None
# AR03          CongressmanWomack
# AR04                       None
# AZ01                       None
# AZ02                       None
# AZ03           raulgrijalvaaz07
# AZ04                   repgosar
# AZ05                       None
# AZ06         RepDavidSchweikert
# AZ07                       None
# AZ09                  repsinema
# CA01                 RepLaMalfa
# CA02                 rephuffman
# CA03              garamendiCA10
# CA04             McClintockCA04
# CA05       CongressmanMThompson
# CA06             RepDorisMatsui
# CA07                 repamibera
# CA08                RepPaulCook
# CA09           RepJerryMcNerney
# CA10              repjeffdenham
# ...                         ...
# VA05   UC_lWS6tnQPcBPlmD2e99zKw
# VA06            RepBobGoodlatte
# VA07                       None
# VA08                       None
# VA09          RepMorganGriffith
# VA10                       None
# VA11                repconnolly
# VT00              reppeterwelch
# WA01                       None
# WA02          congressmanlarsen
# WA03          RepHerreraBeutler
# WA04                       None
# WA05            mcmorrisrodgers
# WA06                       None
# WA07                       None
# WA08            repdavereichert
# WA09       CongressmanAdamSmith
# WA10               RepDennyHeck
# WI01                reppaulryan
# WI02               repmarkpocan
# WI03                 RepRonKind
# WI04               RepGwenMoore
# WI05           RepSensenbrenner
# WI06                       None
# WI07               RepSeanDuffy
# WI08                       None
# WV01           RepDavidMcKinley
# WV02                       None
# WV03                       None
# WY00                       None
#
# [429 rows x 53 columns]

# %%
dm.simple_map_html(total_df,"remain.html")

# %%
total_df['in_office']
# Out:
# ident
# AK00     True
# AL01     True
# AL02     True
# AL03     True
# AL04     True
# AL05     True
# AL06     True
# AL07     True
# AR01     True
# AR02     True
# AR03     True
# AR04     True
# AZ01     True
# AZ02     True
# AZ03     True
# AZ04     True
# AZ05     True
# AZ06     True
# AZ07     True
# AZ08    False
# AZ09     True
# CA01     True
# CA02     True
# CA03     True
# CA04     True
# CA05     True
# CA06     True
# CA07     True
# CA08     True
# CA09     True
#         ...
# VA05     True
# VA06     True
# VA07     True
# VA08     True
# VA09     True
# VA10     True
# VA11     True
# VT00     True
# WA01     True
# WA02     True
# WA03     True
# WA04     True
# WA05     True
# WA06     True
# WA07     True
# WA08     True
# WA09     True
# WA10     True
# WI01     True
# WI02     True
# WI03     True
# WI04     True
# WI05     True
# WI06     True
# WI07     True
# WI08     True
# WV01     True
# WV02     True
# WV03     True
# WY00     True
# Name: in_office, Length: 442, dtype: object

# %% [markdown]
#  Wikipedia image scrape by name.

# %%
import wikipedia
import requests
name1 = "Ralph Abraham"
ny1 = wikipedia.search(name1)
name = name1
for n in ny1:
    if "(politician)" in n:
        name = n
ny = wikipedia.page(name)
print(ny)
print(ny.images)

img_data = requests.get(ny.images[0]).content
with open(ny.title+'.jpg', 'wb') as handler:
    handler.write(img_data)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1715         result = _lib.SSL_do_handshake(self._ssl)
# -> 1716         self._raise_ssl_error(self._ssl, result)
#    1717
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1455         else:
# -> 1456             _raise_current_error()
#    1457
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?list=search&srprop=&srlimit=10&limit=10&srsearch=Ralph+Abraham&format=json&action=query (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Documents\GitHub\USA_in_Data\Server.py in <module>()
#       2 import requests
#       3 name1 = "Ralph Abraham"
# ----> 4 ny1 = wikipedia.search(name1)
#       5 name = name1
#       6 for n in ny1:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wikipedia\util.py in __call__(self, *args, **kwargs)
#      26       ret = self._cache[key]
#      27     else:
# ---> 28       ret = self._cache[key] = self.fn(*args, **kwargs)
#      29
#      30     return ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wikipedia\wikipedia.py in search(query, results, suggestion)
#     101     search_params['srinfo'] = 'suggestion'
#     102
# --> 103   raw_results = _wiki_request(search_params)
#     104
#     105   if 'error' in raw_results:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wikipedia\wikipedia.py in _wiki_request(params)
#     735     time.sleep(int(wait_time.total_seconds()))
#     736
# --> 737   r = requests.get(API_URL, params=params, headers=headers)
#     738
#     739   if RATE_LIMIT:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?list=search&srprop=&srlimit=10&limit=10&srsearch=Ralph+Abraham&format=json&action=query (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
